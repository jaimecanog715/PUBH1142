# %% [markdown]
# # Chapter 7: PYTHON COLLECTIONS
# **Name** Jaime Cano García

# %% [markdown]
# ### Task 1

# %%
# Create a tuple with the first seven prime numbers
primes = (2, 3, 5, 7, 11, 13, 17)

# Return the last three prime numbers
primes[-3:]

# %% [markdown]
# ### Task 2

# %%
# Given sets
set_A = {'a', 'b', 'c', 'd', 'e', 'f'}
set_B = {'a', 'c', 'f', 'g'}

# Original difference
set_A.difference(set_B)

# Reverse difference
set_B.difference(set_A)

# %% [markdown]
# ### Quiz

# %%
# 1. Define a list
my_list = [1, 2, 3]

# 2. Access the third element
my_list[2]

# 3. Add "new_item" to the end
my_list.append("new_item")

# 4. Create a tuple
my_tuple = ("apple", "banana", "cherry")

# 5. Access first element of tuple
my_tuple[0]

# 6. Define a dictionary
my_dict = {"name": "John Doe", "age": 30}

# 7. Retrieve value for "name"
my_dict["name"]

# 8. Change value of "age"
my_dict["age"] = 35

# 9. Add new key-value pair
my_dict["city"] = "New York"

# 10. Create a set
my_set = {"apple", "banana", "cherry"}

# 11. Add "orange" to set
my_set.add("orange")

# 12. Remove "banana"
my_set.remove("banana")

# 13. Length of list
len([1, 2, 3, 4, 5])

# 14. Result of list repetition
[1, 2, 3] * 2

# 15. Result of set with duplicates removed
set([1,2,2,3,4,4,4,5,5])
